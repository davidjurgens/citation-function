# %%
#install.packages("glmmADMB")
#install.packages("R2admb")
#install.packages("glmmADMB", 
#    repos=c("http://glmmadmb.r-forge.r-project.org/repos",
#            getOption("repos")),
#    type="source")
# Out:
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done
# Updating HTML index of packages in '.Library'
# Making 'packages.html' ... done

# %%
library(lme4) 
library(arm) 
# library(lmerTest)
require(MuMIn)
require(sjPlot)
library(sjPlot)
require(sjmisc)
require(fmsb)
require(VIF)
require(MASS)
library(stargazer)
library(data.table)
library(nlme)
library(piecewiseSEM)
library(popbio)
library(xtable)
library(IRdisplay)
library(repr)
library(Hmisc)
library(glmmADMB)
library(pscl)
require(ggplot2)
require(pscl)
require(boot)
# Out:
# Loading required package: Matrix
# Loading required package: MASS
#
# arm (Version 1.9-3, built: 2016-11-21)
#
# Working directory is /Users/jurgens/Documents/Stanford/citation-function/new/analysis
#
# Loading required package: MuMIn
# Loading required package: sjPlot
# Loading required package: sjmisc
# Loading required package: fmsb
# Loading required package: VIF
#
# Please cite as:
#
#  Hlavac, Marek (2015). stargazer: Well-Formatted Regression and Summary Statistics Tables.
#  R package version 5.2. http://CRAN.R-project.org/package=stargazer
#
#
# Attaching package: ‘nlme’
#
# The following object is masked from ‘package:lme4’:
#
#     lmList
#
#
# Attaching package: ‘xtable’
#
# The following object is masked from ‘package:arm’:
#
#     display
#
#
# Attaching package: ‘IRdisplay’
#
# The following object is masked from ‘package:xtable’:
#
#     display
#
# The following object is masked from ‘package:arm’:
#
#     display
#
# Loading required package: lattice
# ...

# %%
print('asf')
# Out:
# [1] "asf"

# %%
help("glmm.admb")

# %%
how_cites_df <- read.csv("../working-files/how-cites.reg-data.custom-weights6.tsv", header = TRUE, sep = "\t")

# %%
summary(how_cites_df)

# %%
vif_func<-function(in_frame,thresh=10,trace=T,...){

  require(fmsb)
  
  if(class(in_frame) != 'data.frame') in_frame<-data.frame(in_frame)
  
  #get initial vif value for all comparisons of variables
  vif_init<-NULL
  var_names <- names(in_frame)
  for(val in var_names){
      regressors <- var_names[-which(var_names == val)]
      form <- paste(regressors, collapse = '+')
      form_in <- formula(paste(val, '~', form))
      vif_init<-rbind(vif_init, c(val, VIF(lm(form_in, data = in_frame, ...))))
      }
  vif_max<-max(as.numeric(vif_init[,2]), na.rm = TRUE)

  if(vif_max < thresh){
    if(trace==T){ #print output of each iteration
        prmatrix(vif_init,collab=c('var','vif'),rowlab=rep('',nrow(vif_init)),quote=F)
        cat('\n')
        cat(paste('All variables have VIF < ', thresh,', max VIF ',round(vif_max,2), sep=''),'\n\n')
        }
    return(var_names)
    }
  else{

    in_dat<-in_frame

    #backwards selection of explanatory variables, stops when all VIF values are below 'thresh'
    while(vif_max >= thresh){
      
      vif_vals<-NULL
      var_names <- names(in_dat)
        
      for(val in var_names){
        regressors <- var_names[-which(var_names == val)]
        form <- paste(regressors, collapse = '+')
        form_in <- formula(paste(val, '~', form))
        vif_add<-VIF(lm(form_in, data = in_dat, ...))
        vif_vals<-rbind(vif_vals,c(val,vif_add))
        }
      max_row<-which(vif_vals[,2] == max(as.numeric(vif_vals[,2]), na.rm = TRUE))[1]

      vif_max<-as.numeric(vif_vals[max_row,2])

      if(vif_max<thresh) break
      
      if(trace==T){ #print output of each iteration
        prmatrix(vif_vals,collab=c('var','vif'),rowlab=rep('',nrow(vif_vals)),quote=F)
        cat('\n')
        cat('removed: ',vif_vals[max_row,1],vif_max,'\n\n')
        flush.console()
        }

      in_dat<-in_dat[,!names(in_dat) %in% vif_vals[max_row,1]]

      }

    return(names(in_dat))
    
    }
  
  }

# %%
#vif_func(how_cites_df)
cat('test')
# Out:
# test

# %%
cols <- names(how_cites_df)
xcols <- c('venue', 'venue_type')
numeric_cols <- cols[!cols %in% xcols]
paste(numeric_cols, collapse=' + ')
# Out:
# [1] "X + Background + CompareOrContrast + Extends + Future + Motivation + Topic_0 + Topic_1 + Topic_10 + Topic_11 + Topic_12 + Topic_13 + Topic_14 + Topic_15 + Topic_16 + Topic_17 + Topic_18 + Topic_19 + Topic_2 + Topic_20 + Topic_21 + Topic_22 + Topic_23 + Topic_24 + Topic_25 + Topic_26 + Topic_27 + Topic_28 + Topic_29 + Topic_3 + Topic_30 + Topic_31 + Topic_32 + Topic_33 + Topic_34 + Topic_35 + Topic_36 + Topic_37 + Topic_38 + Topic_39 + Topic_4 + Topic_40 + Topic_41 + Topic_42 + Topic_43 + Topic_44 + Topic_45 + Topic_46 + Topic_47 + Topic_48 + Topic_49 + Topic_5 + Topic_50 + Topic_51 + Topic_52 + Topic_53 + Topic_54 + Topic_55 + Topic_56 + Topic_57 + Topic_58 + Topic_59 + Topic_6 + Topic_60 + Topic_61 + Topic_62 + Topic_63 + Topic_64 + Topic_65 + Topic_66 + Topic_67 + Topic_68 + Topic_69 + Topic_7 + Topic_70 + Topic_71 + Topic_72 + Topic_73 + Topic_74 + Topic_75 + Topic_76 + Topic_77 + Topic_78 + Topic_79 + Topic_8 + Topic_80 + Topic_81 + Topic_82 + Topic_83 + Topic_84 + Topic_85 
# ...

# %%
bg_partial <- lm(Background ~ num_outcites, data = how_cites_df)
cc_partial <- lm(CompareOrContrast ~ num_outcites, data = how_cites_df)
ex_partial <- lm(Extends ~ num_outcites, data = how_cites_df)
fu_partial <- lm(Future ~ num_outcites, data = how_cites_df)
mo_partial <- lm(Motivation ~ num_outcites, data = how_cites_df)
us_partial <- lm(Uses ~ num_outcites, data = how_cites_df)

# %%
how_cites_df$Background.p <- bg_partial$resid
how_cites_df$CompareOrContrast.p <- cc_partial$resid
how_cites_df$Extends.p <- ex_partial$resid
how_cites_df$Future.p <- fu_partial$resid
how_cites_df$Motivation.p <- mo_partial$resid
how_cites_df$Uses.p <- us_partial$resid

#summary(bg_partial)

# %%
group_m <- glmer(dependent_var ~ Topic_1 + Topic_10 + Topic_11 + Topic_12 + Topic_13 + Topic_14 + Topic_15 + Topic_16 + Topic_17 + Topic_18 + Topic_19 + Topic_2 + Topic_20 + Topic_21 + Topic_22 + Topic_23 + Topic_24 + Topic_25 + Topic_26 + Topic_27 + Topic_28 + Topic_29 + Topic_3 + Topic_30 + Topic_31 + Topic_32 + Topic_33 + Topic_34 + Topic_35 + Topic_36 + Topic_37 + Topic_38 + Topic_39 + Topic_4 + Topic_40 + Topic_41 + Topic_42 + Topic_43 + Topic_44 + Topic_45 + Topic_46 + Topic_47 + Topic_48 + Topic_49 + Topic_5 + Topic_50 + Topic_51 + Topic_52 + Topic_53 + Topic_54 + Topic_55 + Topic_56 + Topic_57 + Topic_58 + Topic_59 + Topic_6 + Topic_60 + Topic_61 + Topic_62 + Topic_63 + Topic_64 + Topic_65 + Topic_66 + Topic_67 + Topic_68 + Topic_69 + Topic_7 + Topic_70 + Topic_71 + Topic_72 + Topic_73 + Topic_74 + Topic_75 + Topic_76 + Topic_77 + Topic_78 + Topic_79 + Topic_8 + Topic_80 + Topic_81 + Topic_82 + Topic_83 + Topic_84 + Topic_85 + Topic_86 + Topic_87 + Topic_88 + Topic_89 + Topic_9 + Topic_90 + Topic_91 + Topic_92 + Topic_93 + Topic_94 + Topic_95 + Topic_96 + Topic_97 + Topic_98 + Topic_99 +  num_authors
                    + num_outcites +  topic_diversity + year + (1 | venue), data = how_cites_df, 
                    verbose=TRUE, control = glmerControl(optimizer = "nloptwrap"))

# %%
with_funcs <- lmer(dependent_var ~ Background + CompareOrContrast + Extends + Future + Motivation + Prior + Uses + 
                    num_authors + num_outcites +  topic_diversity + year +
                    Topic_1 + Topic_10 + Topic_11 + Topic_12 + Topic_13 + Topic_14 + Topic_15 + Topic_16 + Topic_17 + Topic_18 + Topic_19 + Topic_2 + Topic_20 + Topic_21 + Topic_22 + Topic_23 + Topic_24 + Topic_25 + Topic_26 + Topic_27 + Topic_28 + Topic_29 + Topic_3 + Topic_30 + Topic_31 + Topic_32 + Topic_33 + Topic_34 + Topic_35 + Topic_36 + Topic_37 + Topic_38 + Topic_39 + Topic_4 + Topic_40 + Topic_41 + Topic_42 + Topic_43 + Topic_44 + Topic_45 + Topic_46 + Topic_47 + Topic_48 + Topic_49 + Topic_5 + Topic_50 + Topic_51 + Topic_52 + Topic_53 + Topic_54 + Topic_55 + Topic_56 + Topic_57 + Topic_58 + Topic_59 + Topic_6 + Topic_60 + Topic_61 + Topic_62 + Topic_63 + Topic_64 + Topic_65 + Topic_66 + Topic_67 + Topic_68 + Topic_69 + Topic_7 + Topic_70 + Topic_71 + Topic_72 + Topic_73 + Topic_74 + Topic_75 + Topic_76 + Topic_77 + Topic_78 + Topic_79 + Topic_8 + Topic_80 + Topic_81 + Topic_82 + Topic_83 + Topic_84 + Topic_85 + Topic_86 + Topic_87 + Topic_88 + Topic_89 + Topic_9 + Topic_90 + Topic_91 + Topic_92 + Topic_93 + Topic_94 + Topic_95 + Topic_96 + Topic_97 + Topic_98 + Topic_99 
                    + (1 | venue), 
                    data = how_cites_df, 
                    verbose=TRUE)

# %%
with_funcs.nb <- glm.nb(dependent_var ~ Background.p + CompareOrContrast.p + Extends.p + Future.p
                        + Motivation.p + Uses.p
                        + num_authors + num_outcites +  topic_diversity + year 
                        + venue, 
                        data = how_cites_df)

# %%
with_funcs.hurdle <- hurdle(dependent_var ~ Background.p + CompareOrContrast.p + Extends.p + Future.p
                        + Motivation.p + Uses.p
                        + num_authors + num_outcites +  topic_diversity + year 
                        + venue, 
                        data = how_cites_df)
# Out:
# Error in solve.default(as.matrix(fit_count$hessian)): Lapack routine dgesv: system is exactly singular: U[19,19] = 0
# Traceback:
#
# 1. hurdle(dependent_var ~ Background.p + CompareOrContrast.p + Extends.p +
#  .     Future.p + Motivation.p + Uses.p + num_authors + num_outcites +
#  .     topic_diversity + year + venue, data = how_cites_df)
# 2. solve(as.matrix(fit_count$hessian))
# 3. solve.default(as.matrix(fit_count$hessian))

# %%
with_funcs.zeroinf_poi <- zeroinfl(dependent_var ~ Background.p + CompareOrContrast.p + Extends.p + Future.p
                        + Motivation.p + Uses.p
                        + num_authors + num_outcites +  topic_diversity + year 
                        + venue | Background.p + CompareOrContrast.p + Extends.p + Future.p
                        + Motivation.p + Uses.p
                        + num_authors + num_outcites +  topic_diversity + year 
                        + venue, 
                        data = how_cites_df)
# Out:
# Error in solve.default(as.matrix(fit$hessian)): system is computationally singular: reciprocal condition number = 2.63197e-43
# Traceback:
#
# 1. zeroinfl(dependent_var ~ Background.p + CompareOrContrast.p +
#  .     Extends.p + Future.p + Motivation.p + Uses.p + num_authors +
#  .     num_outcites + topic_diversity + year + venue | Background.p +
#  .     CompareOrContrast.p + Extends.p + Future.p + Motivation.p +
#  .     Uses.p + num_authors + num_outcites + topic_diversity + year +
#  .     venue, data = how_cites_df)
# 2. solve(as.matrix(fit$hessian))
# 3. solve.default(as.matrix(fit$hessian))

# %%
without_funcs.zeroinf_poi <- zeroinfl(dependent_var ~ num_authors + num_outcites +  topic_diversity + year 
                        + venue | num_authors + num_outcites +  topic_diversity + year 
                        + venue, 
                        data = how_cites_df)

# %%
without_funcs.nb <- glm.nb(dependent_var ~ num_authors + num_outcites +  topic_diversity + year 
                        + venue, 
                        data = how_cites_df)

# %%
with_funcs.nb <- glm.nb(dependent_var ~ Background + CompareOrContrast + Extends + Future + Motivation + Prior + Uses + 
                    num_authors + num_outcites +  topic_diversity + year +
                    # Topic_1 + Topic_10 + Topic_11 + Topic_12 + Topic_13 + Topic_14 + Topic_15 + Topic_16 + Topic_17 + Topic_18 + Topic_19 + Topic_2 + Topic_20 + Topic_21 + Topic_22 + Topic_23 + Topic_24 + Topic_25 + Topic_26 + Topic_27 + Topic_28 + Topic_29 + Topic_3 + Topic_30 + Topic_31 + Topic_32 + Topic_33 + Topic_34 + Topic_35 + Topic_36 + Topic_37 + Topic_38 + Topic_39 + Topic_4 + Topic_40 + Topic_41 + Topic_42 + Topic_43 + Topic_44 + Topic_45 + Topic_46 + Topic_47 + Topic_48 + Topic_49 + Topic_5 + Topic_50 + Topic_51 + Topic_52 + Topic_53 + Topic_54 + Topic_55 + Topic_56 + Topic_57 + Topic_58 + Topic_59 + Topic_6 + Topic_60 + Topic_61 + Topic_62 + Topic_63 + Topic_64 + Topic_65 + Topic_66 + Topic_67 + Topic_68 + Topic_69 + Topic_7 + Topic_70 + Topic_71 + Topic_72 + Topic_73 + Topic_74 + Topic_75 + Topic_76 + Topic_77 + Topic_78 + Topic_79 + Topic_8 + Topic_80 + Topic_81 + Topic_82 + Topic_83 + Topic_84 + Topic_85 + Topic_86 + Topic_87 + Topic_88 + Topic_89 + Topic_9 + Topic_90 + Topic_91 + Topic_92 + Topic_93 + Topic_94 + Topic_95 + Topic_96 + Topic_97 + Topic_98 + Topic_99 
                    + venue, 
                    data = how_cites_df)
# Out:
# Error in eval(expr, envir, enclos): object 'Prior' not found
# Traceback:
#
# 1. glm.nb(dependent_var ~ Background + CompareOrContrast + Extends +
#  .     Future + Motivation + Prior + Uses + num_authors + num_outcites +
#  .     topic_diversity + year + +venue, data = how_cites_df)
# 2. eval.parent(mf)
# 3. eval(expr, p)
# 4. eval(expr, envir, enclos)
# 5. stats::model.frame(formula = dependent_var ~ Background + CompareOrContrast +
#  .     Extends + Future + Motivation + Prior + Uses + num_authors +
#  .     num_outcites + topic_diversity + year + +venue, data = how_cites_df,
#  .     drop.unused.levels = TRUE)
# 6. model.frame.default(formula = dependent_var ~ Background + CompareOrContrast +
#  .     Extends + Future + Motivation + Prior + Uses + num_authors +
#  .     num_outcites + topic_diversity + year + +venue, data = how_cites_df,
#  .     drop.unused.levels = TRUE)
# 7. eval(predvars, data, env)
# 8. eval(expr, envir, enclos)

# %%
with_funcs.zinb_me <- glmmadmb(dependent_var ~ Background.p + CompareOrContrast.p + Extends.p + Future.p + Motivation.p + Uses.p +
                    num_authors + num_outcites +  topic_diversity + year +
                    Topic_1 + Topic_10 + Topic_11 + Topic_12 + Topic_13 + Topic_14 + Topic_15 + Topic_16 + Topic_17 + Topic_18 + Topic_19 + Topic_2 + Topic_20 + Topic_21 + Topic_22 + Topic_23 + Topic_24 + Topic_25 + Topic_26 + Topic_27 + Topic_28 + Topic_29 + Topic_3 + Topic_30 + Topic_31 + Topic_32 + Topic_33 + Topic_34 + Topic_35 + Topic_36 + Topic_37 + Topic_38 + Topic_39 + Topic_4 + Topic_40 + Topic_41 + Topic_42 + Topic_43 + Topic_44 + Topic_45 + Topic_46 + Topic_47 + Topic_48 + Topic_49 + Topic_5 + Topic_50 + Topic_51 + Topic_52 + Topic_53 + Topic_54 + Topic_55 + Topic_56 + Topic_57 + Topic_58 + Topic_59 + Topic_6 + Topic_60 + Topic_61 + Topic_62 + Topic_63 + Topic_64 + Topic_65 + Topic_66 + Topic_67 + Topic_68 + Topic_69 + Topic_7 + Topic_70 + Topic_71 + Topic_72 + Topic_73 + Topic_74 + Topic_75 + Topic_76 + Topic_77 + Topic_78 + Topic_79 + Topic_8 + Topic_80 + Topic_81 + Topic_82 + Topic_83 + Topic_84 + Topic_85 + Topic_86 + Topic_87 + Topic_88 + Topic_89 + Topic_9 + Topic_90 + Topic_91 + Topic_92 + Topic_93 + Topic_94 + Topic_95 + Topic_96 + Topic_97 + Topic_98 + Topic_99 
                    + (1 | venue),
         data=how_cites_df, family="nbinom", zeroInflation=TRUE, verbose=TRUE)

# %%
with_funcs.pois <- lmer(dependent_var ~ Background.p + CompareOrContrast.p + Extends.p + Future.p + Motivation.p + Uses.p +
                    num_authors + num_outcites +  topic_diversity + year +
                    Topic_1 + Topic_10 + Topic_11 + Topic_12 + Topic_13 + Topic_14 + Topic_15 + Topic_16 + Topic_17 + Topic_18 + Topic_19 + Topic_2 + Topic_20 + Topic_21 + Topic_22 + Topic_23 + Topic_24 + Topic_25 + Topic_26 + Topic_27 + Topic_28 + Topic_29 + Topic_3 + Topic_30 + Topic_31 + Topic_32 + Topic_33 + Topic_34 + Topic_35 + Topic_36 + Topic_37 + Topic_38 + Topic_39 + Topic_4 + Topic_40 + Topic_41 + Topic_42 + Topic_43 + Topic_44 + Topic_45 + Topic_46 + Topic_47 + Topic_48 + Topic_49 + Topic_5 + Topic_50 + Topic_51 + Topic_52 + Topic_53 + Topic_54 + Topic_55 + Topic_56 + Topic_57 + Topic_58 + Topic_59 + Topic_6 + Topic_60 + Topic_61 + Topic_62 + Topic_63 + Topic_64 + Topic_65 + Topic_66 + Topic_67 + Topic_68 + Topic_69 + Topic_7 + Topic_70 + Topic_71 + Topic_72 + Topic_73 + Topic_74 + Topic_75 + Topic_76 + Topic_77 + Topic_78 + Topic_79 + Topic_8 + Topic_80 + Topic_81 + Topic_82 + Topic_83 + Topic_84 + Topic_85 + Topic_86 + Topic_87 + Topic_88 + Topic_89 + Topic_9 + Topic_90 + Topic_91 + Topic_92 + Topic_93 + Topic_94 + Topic_95 + Topic_96 + Topic_97 + Topic_98 + Topic_99 
                    + venue,
          data=how_cites_df, family="poisson", verbose=TRUE)
# Out:
# Warning message in lmer(dependent_var ~ Background.p + CompareOrContrast.p + Extends.p + :
# “calling lmer with 'family' is deprecated; please use glmer() instead”
# Error: No random effects terms specified in formula
# Traceback:
#
# 1. lmer(dependent_var ~ Background.p + CompareOrContrast.p + Extends.p +
#  .     Future.p + Motivation.p + Uses.p + num_authors + num_outcites +
#  .     topic_diversity + year + Topic_1 + Topic_10 + Topic_11 +
#  .     Topic_12 + Topic_13 + Topic_14 + Topic_15 + Topic_16 + Topic_17 +
#  .     Topic_18 + Topic_19 + Topic_2 + Topic_20 + Topic_21 + Topic_22 +
#  .     Topic_23 + Topic_24 + Topic_25 + Topic_26 + Topic_27 + Topic_28 +
#  .     Topic_29 + Topic_3 + Topic_30 + Topic_31 + Topic_32 + Topic_33 +
#  .     Topic_34 + Topic_35 + Topic_36 + Topic_37 + Topic_38 + Topic_39 +
#  .     Topic_4 + Topic_40 + Topic_41 + Topic_42 + Topic_43 + Topic_44 +
#  .     Topic_45 + Topic_46 + Topic_47 + Topic_48 + Topic_49 + Topic_5 +
# ...

# %%
summary(with_funcs.zinb_me)
# Out:
# Warning message in .local(x, sigma, ...):
# “'sigma' and 'rdig' arguments are present for compatibility only: ignored”
# Call:
# glmmadmb(formula = dependent_var ~ Background + CompareOrContrast +
#     Extends + Future + Motivation + Uses + num_authors + num_outcites +
#     topic_diversity + year + Topic_1 + Topic_10 + Topic_11 +
#     Topic_12 + Topic_13 + Topic_14 + Topic_15 + Topic_16 + Topic_17 +
#     Topic_18 + Topic_19 + Topic_2 + Topic_20 + Topic_21 + Topic_22 +
#     Topic_23 + Topic_24 + Topic_25 + Topic_26 + Topic_27 + Topic_28 +
#     Topic_29 + Topic_3 + Topic_30 + Topic_31 + Topic_32 + Topic_33 +
#     Topic_34 + Topic_35 + Topic_36 + Topic_37 + Topic_38 + Topic_39 +
#     Topic_4 + Topic_40 + Topic_41 + Topic_42 + Topic_43 + Topic_44 +
#     Topic_45 + Topic_46 + Topic_47 + Topic_48 + Topic_49 + Topic_5 +
#     Topic_50 + Topic_51 + Topic_52 + Topic_53 + Topic_54 + Topic_55 +
#     Topic_56 + Topic_57 + Topic_58 + Topic_59 + Topic_6 + Topic_60 +
# ...

# %%
without_funcs <- lmer(dependent_var ~ 
                    num_authors + num_outcites +  topic_diversity + year +
                    Topic_1 + Topic_10 + Topic_11 + Topic_12 + Topic_13 + Topic_14 + Topic_15 + Topic_16 + Topic_17 + Topic_18 + Topic_19 + Topic_2 + Topic_20 + Topic_21 + Topic_22 + Topic_23 + Topic_24 + Topic_25 + Topic_26 + Topic_27 + Topic_28 + Topic_29 + Topic_3 + Topic_30 + Topic_31 + Topic_32 + Topic_33 + Topic_34 + Topic_35 + Topic_36 + Topic_37 + Topic_38 + Topic_39 + Topic_4 + Topic_40 + Topic_41 + Topic_42 + Topic_43 + Topic_44 + Topic_45 + Topic_46 + Topic_47 + Topic_48 + Topic_49 + Topic_5 + Topic_50 + Topic_51 + Topic_52 + Topic_53 + Topic_54 + Topic_55 + Topic_56 + Topic_57 + Topic_58 + Topic_59 + Topic_6 + Topic_60 + Topic_61 + Topic_62 + Topic_63 + Topic_64 + Topic_65 + Topic_66 + Topic_67 + Topic_68 + Topic_69 + Topic_7 + Topic_70 + Topic_71 + Topic_72 + Topic_73 + Topic_74 + Topic_75 + Topic_76 + Topic_77 + Topic_78 + Topic_79 + Topic_8 + Topic_80 + Topic_81 + Topic_82 + Topic_83 + Topic_84 + Topic_85 + Topic_86 + Topic_87 + Topic_88 + Topic_89 + Topic_9 + Topic_90 + Topic_91 + Topic_92 + Topic_93 + Topic_94 + Topic_95 + Topic_96 + Topic_97 + Topic_98 + Topic_99 
                    + (1 | venue), 
                    data = how_cites_df, 
                    verbose=TRUE)

# %%
without_funcs.zinb_me <- glmmadmb(dependent_var ~ 
                    num_authors + num_outcites +  topic_diversity + year +
                    Topic_1 + Topic_10 + Topic_11 + Topic_12 + Topic_13 + Topic_14 + Topic_15 + Topic_16 + Topic_17 + Topic_18 + Topic_19 + Topic_2 + Topic_20 + Topic_21 + Topic_22 + Topic_23 + Topic_24 + Topic_25 + Topic_26 + Topic_27 + Topic_28 + Topic_29 + Topic_3 + Topic_30 + Topic_31 + Topic_32 + Topic_33 + Topic_34 + Topic_35 + Topic_36 + Topic_37 + Topic_38 + Topic_39 + Topic_4 + Topic_40 + Topic_41 + Topic_42 + Topic_43 + Topic_44 + Topic_45 + Topic_46 + Topic_47 + Topic_48 + Topic_49 + Topic_5 + Topic_50 + Topic_51 + Topic_52 + Topic_53 + Topic_54 + Topic_55 + Topic_56 + Topic_57 + Topic_58 + Topic_59 + Topic_6 + Topic_60 + Topic_61 + Topic_62 + Topic_63 + Topic_64 + Topic_65 + Topic_66 + Topic_67 + Topic_68 + Topic_69 + Topic_7 + Topic_70 + Topic_71 + Topic_72 + Topic_73 + Topic_74 + Topic_75 + Topic_76 + Topic_77 + Topic_78 + Topic_79 + Topic_8 + Topic_80 + Topic_81 + Topic_82 + Topic_83 + Topic_84 + Topic_85 + Topic_86 + Topic_87 + Topic_88 + Topic_89 + Topic_9 + Topic_90 + Topic_91 + Topic_92 + Topic_93 + Topic_94 + Topic_95 + Topic_96 + Topic_97 + Topic_98 + Topic_99 
                    + (1 | venue),
         data=how_cites_df, family="nbinom", zeroInflation=TRUE, verbose=TRUE)

# %%
summary(with_funcs.nb)
# Out:
# Call:
# glm.nb(formula = dependent_var ~ Background + CompareOrContrast +
#     Extends + Future + Motivation + Uses + num_authors + num_outcites +
#     topic_diversity + year + venue, data = how_cites_df, init.theta = 0.4930790397,
#     link = log)
#
# Deviance Residuals:
#     Min       1Q   Median       3Q      Max
# -2.1689  -1.0435  -0.5638   0.0668   5.8388
#
# Coefficients:
#                     Estimate Std. Error z value Pr(>|z|)
# (Intercept)       -1.614e+02  7.627e+00 -21.160  < 2e-16 ***
# Background         1.328e-02  5.596e-03   2.373 0.017660 *
# CompareOrContrast  2.496e-02  4.601e-03   5.425 5.80e-08 ***
# Extends            2.127e-02  9.092e-03   2.339 0.019330 *
# Future             1.602e-02  1.346e-02   1.190 0.234035
# Motivation         1.448e-02  7.495e-03   1.931 0.053464 .
# Uses               5.492e-02  5.569e-03   9.862  < 2e-16 ***
# num_authors        1.006e-01  1.159e-02   8.677  < 2e-16 ***
# num_outcites      -3.151e-03  6.663e-03  -0.473 0.636297
# ...

# %%
without_funcs.nb <- glm.nb(dependent_var ~ 
                    num_authors + num_outcites +  topic_diversity + year +
                    Topic_1 + Topic_10 + Topic_11 + Topic_12 + Topic_13 + Topic_14 + Topic_15 + Topic_16 + Topic_17 + Topic_18 + Topic_19 + Topic_2 + Topic_20 + Topic_21 + Topic_22 + Topic_23 + Topic_24 + Topic_25 + Topic_26 + Topic_27 + Topic_28 + Topic_29 + Topic_3 + Topic_30 + Topic_31 + Topic_32 + Topic_33 + Topic_34 + Topic_35 + Topic_36 + Topic_37 + Topic_38 + Topic_39 + Topic_4 + Topic_40 + Topic_41 + Topic_42 + Topic_43 + Topic_44 + Topic_45 + Topic_46 + Topic_47 + Topic_48 + Topic_49 + Topic_5 + Topic_50 + Topic_51 + Topic_52 + Topic_53 + Topic_54 + Topic_55 + Topic_56 + Topic_57 + Topic_58 + Topic_59 + Topic_6 + Topic_60 + Topic_61 + Topic_62 + Topic_63 + Topic_64 + Topic_65 + Topic_66 + Topic_67 + Topic_68 + Topic_69 + Topic_7 + Topic_70 + Topic_71 + Topic_72 + Topic_73 + Topic_74 + Topic_75 + Topic_76 + Topic_77 + Topic_78 + Topic_79 + Topic_8 + Topic_80 + Topic_81 + Topic_82 + Topic_83 + Topic_84 + Topic_85 + Topic_86 + Topic_87 + Topic_88 + Topic_89 + Topic_9 + Topic_90 + Topic_91 + Topic_92 + Topic_93 + Topic_94 + Topic_95 + Topic_96 + Topic_97 + Topic_98 + Topic_99 
                    + venue, 
                    data = how_cites_df)

# %%
summary(with_funcs.nb)

# %%
anova(without_funcs.zinb_me, with_funcs.zinb_me)
# Out:
# Analysis of Deviance Table
#
# Model 1: dependent_var ~ num_authors + num_outcites + topic_diversity + year + Topic_1 + Topic_10 + Topic_11 + Topic_12 + Topic_13 + Topic_14 + Topic_15 + Topic_16 + Topic_17 + Topic_18 + Topic_19 + Topic_2 + Topic_20 + Topic_21 + Topic_22 + Topic_23 + Topic_24 + Topic_25 + Topic_26 + Topic_27 + Topic_28 + Topic_29 + Topic_3 + Topic_30 + Topic_31 + Topic_32 + Topic_33 + Topic_34 + Topic_35 + Topic_36 + Topic_37 + Topic_38 + Topic_39 + Topic_4 + Topic_40 + Topic_41 + Topic_42 + Topic_43 + Topic_44 + Topic_45 +
# ...

# %%
# summary(group_m)
anova(with_funcs.nb, without_funcs.nb)
# Out:
# Likelihood ratio tests of Negative Binomial Models
#
# Response: dependent_var
#                                                                                                                                             Model
# 1                                                                                     num_authors + num_outcites + topic_diversity + year + venue
# 2 Background.p + CompareOrContrast.p + Extends.p + Future.p + Motivation.p + Uses.p + num_authors + num_outcites + topic_diversity + year + venue
#       theta Resid. df    2 x log-lik.   Test    df LR stat. Pr(Chi)
# 1 0.4791041     10073       -34969.40
# 2 0.4930790     10067       -34831.63 1 vs 2     6 137.7635       0

# %%
stargazer(without_funcs.nb, with_funcs.nb)
# Out:
# % Table created by stargazer v.5.2 by Marek Hlavac, Harvard University. E-mail: hlavac at fas.harvard.edu
# % Date and time: Mon, Jul 31, 2017 - 23:10:03
# \begin{table}[!htbp] \centering
#   \caption{}
#   \label{}
# \begin{tabular}{@{\extracolsep{5pt}}lcc}
# \\[-1.8ex]\hline
# \hline \\[-1.8ex]
#  & \multicolumn{2}{c}{\textit{Dependent variable:}} \\
# \cline{2-3}
# \\[-1.8ex] & \multicolumn{2}{c}{dependent\_var} \\
# \\[-1.8ex] & (1) & (2)\\
# \hline \\[-1.8ex]
#  Background.p &  & 0.013$^{**}$ \\
#   &  & (0.006) \\
#   & & \\
#  CompareOrContrast.p &  & 0.025$^{***}$ \\
#   &  & (0.005) \\
#   & & \\
#  Extends.p &  & 0.021$^{**}$ \\
#   &  & (0.009) \\
#   & & \\
#  Future.p &  & 0.016 \\
#   &  & (0.013) \\
#   & & \\
#  Motivation.p &  & 0.014$^{*}$ \\
#   &  & (0.007) \\
#   & & \\
#  Uses.p &  & 0.055$^{***}$ \\
#   &  & (0.006) \\
#   & & \\
#  num\_authors & 0.101$^{***}$ & 0.101$^{***}$ \\
#   & (0.012) & (0.012) \\
#   & & \\
# ...
